# %%
# Change directory to the parent folder to access the dataset
import os
os.chdir('../')
print(os.getcwd())

os.chdir('../')
print(os.getcwd())


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# c:\Users\mathi\Documents\2. Skole\Master\2. Semester\TEP4222 Kryssløpsanalyse, handel og miljø\Project\Input-Output
# c:\Users\mathi\Documents\2. Skole\Master\2. Semester\TEP4222 Kryssløpsanalyse, handel og miljø\Project

# %%
# Importing the CSV files
F_sanctioned = pd.read_csv("Input-Output/Calculated data/F_sanctioned.csv")
x_star = pd.read_csv("Input-Output/Calculated data/x_star.csv")

# Display the imported data (optional)
print("F_sanctioned:")
display(F_sanctioned.head())

print("\nX_star:")
display(x_star)
# Out:
# F_sanctioned:
#    region                    AT                              AT.1  \
# 0  sector  Cultivation of wheat  Cultivation of cereal grains nec
# 1       0                   0.0                               0.0
#
#                                      AT.2                      AT.3  \
# 0  Cultivation of vegetables, fruit, nuts  Cultivation of oil seeds
# 1                                     0.0                       0.0
#
#                                     AT.4                               AT.5  \
# 0  Cultivation of sugar cane, sugar beet  Cultivation of plant-based fibers
# 1                                    0.0                                0.0
#
#                        AT.6            AT.7          AT.8  ...  \
# 0  Cultivation of crops nec  Cattle farming  Pigs farming  ...
# 1                       0.0             0.0           0.0  ...
#
#                      WM.153                      WM.154  \
# 0  Landfill of waste: Paper  Landfill of waste: Plastic
# ...
